# %% [markdown]
# ## Установка зависимостей

# %%
# !pip install gdown &> /dev/null

# %%
# !pip install peft &> /dev/null

# %%
# !git clone https://github.com/huggingface/diffusers &> /dev/null
# %pip install git+https://github.com/huggingface/diffusers &> /dev/null
# %pip install triton &> /dev/null
# %pip install accelerate transformers ftfy gradio natsort safetensors &> /dev/null
# %pip install bitsandbytes &> /dev/null
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Скачиваем модель

# %%
# !wget https://raw.githubusercontent.com/CompVis/stable-diffusion/main/configs/stable-diffusion/v1-inference.yaml
# Out:
# --2024-04-11 19:23:53--  https://raw.githubusercontent.com/CompVis/stable-diffusion/main/configs/stable-diffusion/v1-inference.yaml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1873 (1.8K) [text/plain]
# Saving to: 'v1-inference.yaml'
#
# v1-inference.yaml   100%[===================>]   1.83K  --.-KB/s    in 0s
#
# 2024-04-11 19:23:53 (23.9 MB/s) - 'v1-inference.yaml' saved [1873/1873]

# %%
# !wget -O civitai_midel.ckpt 'https://civitai.com/api/download/models/201259?type=Model&format=SafeTensor&size=pruned&fp=fp16'
# Out:
# --2024-04-11 19:23:54--  https://civitai.com/api/download/models/201259?type=Model&format=SafeTensor&size=pruned&fp=fp16
# Resolving civitai.com (civitai.com)... 104.18.23.206, 104.18.22.206, 2606:4700::6812:17ce, ...
# Connecting to civitai.com (civitai.com)|104.18.23.206|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/81744/epicphotogasmz.VG6S.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22epicphotogasm_zUniversal.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240411/us-east-1/s3/aws4_request&X-Amz-Date=20240411T192354Z&X-Amz-SignedHeaders=host&X-Amz-Signature=9b65c2e85ecad5e43231baefe2b436c6405289d069c0ca773f5a2bf230fb82f0 [following]
# --2024-04-11 19:23:55--  https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/81744/epicphotogasmz.VG6S.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22epicphotogasm_zUniversal.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240411/us-east-1/s3/aws4_request&X-Amz-Date=20240411T192354Z&X-Amz-SignedHeaders=host&X-Amz-Signature=9b65c2e85ecad5e43231baefe2b436c6405289d069c0ca773f5a2bf230fb82f0
# Resolving civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)... 104.18.9.90, 104.18.8.90, 2606:4700::6812:85a, ...
# Connecting to civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)|104.18.9.90|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2132625628 (2.0G) [application/octet-stream]
# Saving to: 'civitai_midel.ckpt'
#
# civitai_midel.ckpt  100%[===================>]   1.99G  62.9MB/s    in 42s
#
# 2024-04-11 19:24:37 (48.8 MB/s) - 'civitai_midel.ckpt' saved [2132625628/2132625628]

# %%
# !python diffusers/scripts/convert_original_stable_diffusion_to_diffusers.py \
     --checkpoint_path='civitai_midel.ckpt'\
     --original_config_file='v1-inference.yaml'\
     --dump_path='/kaggle/working/cache_dir/models/civitai_model'\
     --scheduler_type="ddim" --prediction_type='epsilon'\
     --from_safetensors
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# 2024-04-11 19:24:45.920969: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-11 19:24:45.921091: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-11 19:24:46.046619: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# config.json: 100%|█████████████████████████| 4.52k/4.52k [00:00<00:00, 18.8MB/s]
# tokenizer_config.json: 100%|███████████████████| 905/905 [00:00<00:00, 3.97MB/s]
# vocab.json: 100%|████████████████████████████| 961k/961k [00:00<00:00, 13.9MB/s]
# merges.txt: 100%|████████████████████████████| 525k/525k [00:00<00:00, 38.0MB/s]
# special_tokens_map.json: 100%|█████████████████| 389/389 [00:00<00:00, 2.00MB/s]
# tokenizer.json: 100%|██████████████████████| 2.22M/2.22M [00:00<00:00, 12.4MB/s]
# config.json: 100%|█████████████████████████| 4.55k/4.55k [00:00<00:00, 14.6MB/s]
# pytorch_model.bin: 100%|████████████████████| 1.22G/1.22G [00:05<00:00, 209MB/s]
# /opt/conda/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# preprocessor_config.json: 100%|████████████████| 342/342 [00:00<00:00, 1.64MB/s]
# /opt/conda/lib/python3.10/site-packages/transformers/models/clip/feature_extraction_clip.py:28: FutureWarning: The class CLIPFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use CLIPImageProcessor instead.
#   warnings.warn(

# %%
# !cp -r /kaggle/working/cache_dir/models/civitai_model/ /kaggle/working/civitai_weights

# %%
# !rm -rf /kaggle/working/cache_dir/

# %% [markdown]
# ## Импорты и константы

# %%
import gdown
import os
import torch
from torch import autocast
from diffusers.utils import load_image
from diffusers import StableDiffusionPipeline, DDIMScheduler
from IPython.display import display
import os
from pathlib import Path
from diffusers import UniPCMultistepScheduler
from IPython.display import Image as IPyImage, display
from PIL import Image
from diffusers import StableDiffusionControlNetPipeline, ControlNetModel
import torch
import cv2
from PIL import Image
import numpy as np
# Out:
# 2024-04-11 19:25:47.933898: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-11 19:25:47.933963: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-11 19:25:47.935642: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# ## Готовим датасет

# %%
output  = 'freddie.zip'
id = "1hgi_d4mRFv2liZwq_hi8n1KZjIw0pmic"
gdown.download(id=id, output=output)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1hgi_d4mRFv2liZwq_hi8n1KZjIw0pmic
# To: /kaggle/working/freddie.zip
# 100%|██████████| 657k/657k [00:00<00:00, 85.8MB/s]
# 'freddie.zip'

# %%
# !unzip 'freddie.zip' -d ./freddie
# Out:
# Archive:  freddie.zip
#  extracting: ./freddie/5b6d7f653d2d612837956d41aee7ade5.jpg
#  extracting: ./freddie/9c0cd0bfac2039cbeb2353fb74972.jpg
#  extracting: ./freddie/61b80d5f644c8e3dfc16221150fc85bc.jpg
#  extracting: ./freddie/90.jpg
#  extracting: ./freddie/480x497_0xac120003_2925960751567524438.jpg
#  extracting: ./freddie/1599252890187245341.jpg
#  extracting: ./freddie/AQACucAAN4X9NGsDXcT2JsPEs6LfUhVq6ccaRzfR3pDQ1L7mcP9Mx7tix4jTMCq_EAYMH6SK15xCU75uKfSEeSthcX8.jpg
#  extracting: ./freddie/b8324faa005d4081cd95fc82ac11f9c8_cropped_666x996.jpg
#  extracting: ./freddie/big-person-15674314621.jpg
#  extracting: ./freddie/cKg1Qn_G4VU.jpg
#  extracting: ./freddie/d7b5ccd32d639c265eeda817ed787476.jpg
#  extracting: ./freddie/da161d93875e0147bf1eba02e0e434d7.jpg
#  extracting: ./freddie/e7ebfdb9a7b6821acf524272994f27e1.jpg
#  extracting: ./freddie/ed59571d645b880df2015bcdd99baee3.jpg
#  extracting: ./freddie/f4efe7d98e0096310587a9ad9b7e1836.jpg
#  extracting: ./freddie/freddie-mercury.jpg
#  extracting: ./freddie/hqdefault.jpg
#  extracting: ./freddie/scale_1200 (1).jpeg
#  extracting: ./freddie/#U0421#U041f#U0418#U0414-853x1024.jpg

# %%
# !rm -rf freddie.zip

# %% [markdown]
# ## Готовим датасет для class_dir

# %% [markdown]
# Необходимо, чтобы не было только переднего плана в генерации персонажа

# %%
#  в первый разу обучала, генерила
# !mkdir /kaggle/working/man_images

output  = 'man_images.zip'
id = "1el1pk6BS5AQKLasm9uwIuVXAP4nbPesH"
gdown.download(id=id, output=output)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1el1pk6BS5AQKLasm9uwIuVXAP4nbPesH
# To: /kaggle/working/man_images.zip
# 100%|██████████| 4.64M/4.64M [00:00<00:00, 232MB/s]
# 'man_images.zip'

# %%
# !unzip 'man_images.zip' -d /
# Out:
# Archive:  man_images.zip
#    creating: /kaggle/working/man_images/
#   inflating: /kaggle/working/man_images/145-98f971c114daf7fdbc1143c0ed9542898965954b.jpg
#   inflating: /kaggle/working/man_images/206-85207cb2a8254ad1ece748b04e83c76fbe08f2d8.jpg
#   inflating: /kaggle/working/man_images/77-d641f1c480a8736bf3c7aa1c8da6cba18aa615ec.jpg
#   inflating: /kaggle/working/man_images/204-736bd3fccd26d05d47b2507c218376dd64d9d9fd.jpg
#   inflating: /kaggle/working/man_images/164-211d7a63a600a77efc05bfb94ed219013a700848.jpg
#   inflating: /kaggle/working/man_images/179-387f1710f796629027babb4855d0361ba2978b1f.jpg
#   inflating: /kaggle/working/man_images/155-0c170ca57816e41772e92e77105fe57cf18f3095.jpg
#   inflating: /kaggle/working/man_images/220-a3e7eb7cb3156d520e39354952726a55b433359c.jpg
#   inflating: /kaggle/working/man_images/65-9aec2f7c216bf6e09073df69ce580339f6cb2002.jpg
#   inflating: /kaggle/working/man_images/188-7264e3405d3ed3eb00c54a2256a1c4f8cb32e615.jpg
#   inflating: /kaggle/working/man_images/23-916b672b4e3e2d0dea327a1cb74e6f2b55c1f0a8.jpg
#   inflating: /kaggle/working/man_images/119-3c97d488668d672f7b863f6f88a0c81c94b56000.jpg
#   inflating: /kaggle/working/man_images/219-c32654653f39083035458055e30d5264a5cfee9e.jpg
#   inflating: /kaggle/working/man_images/125-297738c24be51aa48f3e2016f9c9d1f2ebdedf68.jpg
#   inflating: /kaggle/working/man_images/180-0e39a6e304c8f2031e6eecef9e04f6c1307b246e.jpg
#   inflating: /kaggle/working/man_images/7-f633f60698cac5c595f08112d1658616e8f30212.jpg
#   inflating: /kaggle/working/man_images/42-20d5b5f76eeecb3d03cae7c399b38c7fbcbe4920.jpg
#   inflating: /kaggle/working/man_images/67-0573d10b811138dc99f4eeb73de8c9abf2dc992d.jpg
#   inflating: /kaggle/working/man_images/136-2e5a77703a10c7dac5a1e7afa48b75aa830fef72.jpg
#   inflating: /kaggle/working/man_images/158-88c92c030082937fc2478b22edba7ca8b2a7aa98.jpg
#   inflating: /kaggle/working/man_images/34-fa85c70d77e0737324ff2849dde4a97df0aff7af.jpg
#   inflating: /kaggle/working/man_images/30-82ff4247488bb1e642e5a9cbe64ba9ddfa66681f.jpg
#   inflating: /kaggle/working/man_images/216-445cc05ed6b101841f3d612fee997b242d201a2d.jpg
#   inflating: /kaggle/working/man_images/129-7f10e44322e3b22e1fe4b125191d6153723c1024.jpg
#   inflating: /kaggle/working/man_images/194-7018ac712a06a1608695af7934383dc1bd9039f6.jpg
#   inflating: /kaggle/working/man_images/116-05fd8e09187714741b20c514654acaf99d677eb5.jpg
#   inflating: /kaggle/working/man_images/12-4ce95a7611f3012a29368cd447ea87ca15c0fb2c.jpg
#   inflating: /kaggle/working/man_images/31-54d5a00c9c9aad05e5be68c3315989b8bde832b7.jpg
#   inflating: /kaggle/working/man_images/100-21f589f65f0b136f12f31ef16a4aaf59b054f608.jpg
#   inflating: /kaggle/working/man_images/81-2e3ee9fb65ae18241b8e6c65dece2b0d0b8ca3f7.jpg
#   inflating: /kaggle/working/man_images/166-481b0c2009bfea07abb1cca3c9d03b99801e7ead.jpg
#   inflating: /kaggle/working/man_images/186-037ec6ff6d0050e3384128459434ae78e15d09ae.jpg
#   inflating: /kaggle/working/man_images/60-d0099002317d4065e5060c4ca4413710ba861750.jpg
#   inflating: /kaggle/working/man_images/190-4d77c8a77f301d9be8ab08095c6fda4086099bad.jpg
#   inflating: /kaggle/working/man_images/176-55258c3ae45dae068a448062d913963255b0c04c.jpg
#   inflating: /kaggle/working/man_images/1-83500e8599bc44ee4f36f03843e2781be383c341.jpg
#   inflating: /kaggle/working/man_images/47-bdfa0957b7a0922957bfcb16408896cb24b95479.jpg
#   inflating: /kaggle/working/man_images/211-cf8cb00a941b2719c9fad1b0ca292db61ae437f8.jpg
#   inflating: /kaggle/working/man_images/227-446bca8e512fe5ded550df9b338dc78f261f8df1.jpg
#   inflating: /kaggle/working/man_images/103-e4e6d7d0c9c84c8b9163d0b14c7dbc20bcafd8d1.jpg
#   inflating: /kaggle/working/man_images/122-cef7499c3884a50064f735eedc19cbc80e2f7547.jpg
#   inflating: /kaggle/working/man_images/109-0a3e0d3535f7a7c1182987658f2038952d61ed01.jpg
#   inflating: /kaggle/working/man_images/147-3f28a647dd6b7d68be9195c42e753931f7078d8b.jpg
#   inflating: /kaggle/working/man_images/33-d72d42f74d678404311a7fc2d5709269f2cabd36.jpg
#   inflating: /kaggle/working/man_images/14-0c4cbae5530f7fbfe24ee1572451bcb1a9413a6c.jpg
#   inflating: /kaggle/working/man_images/41-21fe968c2c049f655685bb2899872f660e938bf0.jpg
#   inflating: /kaggle/working/man_images/74-6bcc88dc3927c85cde77f148135bd308d5a21e9e.jpg
#   inflating: /kaggle/working/man_images/93-40e8768fc8e57c2f7b54d2a570de3eec25362994.jpg
#   inflating: /kaggle/working/man_images/161-712d098a21e46ac4aa6ebb6ef5a60950a24e289e.jpg
#   inflating: /kaggle/working/man_images/198-c0f907e18bd31a3d8355837eaa56718a5087291f.jpg
#   inflating: /kaggle/working/man_images/153-c1cd4d3c92492ac2f979740ca4198fb094c63bce.jpg
#   inflating: /kaggle/working/man_images/4-30a40bfd14af31f6707ece0e634267ec51eee80c.jpg
#   inflating: /kaggle/working/man_images/55-c2585b0724e3bd1533104cdc3f3b4f5067f682a2.jpg
#   inflating: /kaggle/working/man_images/15-81e15e3f797c0306d31054fa91490a76940fef5a.jpg
#   inflating: /kaggle/working/man_images/3-84680614bd04e29d8f86adcfed4d8e580ffe9c11.jpg
#   inflating: /kaggle/working/man_images/191-2cc1d6782bcfb251ae9ce34de191977d8147cd42.jpg
#   inflating: /kaggle/working/man_images/178-54fbbb3d4998749d00c5b8cebfdbb2a85c6764ce.jpg
#   inflating: /kaggle/working/man_images/2-a8049459bd549e1a69bf48c79ea8b026f83a415b.jpg
#   inflating: /kaggle/working/man_images/46-a77c7c0ebcc79ee8cf778f3fadd4226e2af5f3a7.jpg
#   inflating: /kaggle/working/man_images/38-8abf03eabc0c19060a59b0ecedc234f6b1f51fe8.jpg
#   inflating: /kaggle/working/man_images/225-39359139bbcde32126db5424b92c9e5b3e5484a5.jpg
#   inflating: /kaggle/working/man_images/36-049fe822fcbb1eea73f9baca2e8067b738787bea.jpg
#   inflating: /kaggle/working/man_images/45-4a9a2b309ee1cb29db78eb93852152a46f6911a4.jpg
#   inflating: /kaggle/working/man_images/222-4b4a256bfd19cd23013046448cd2db5973a74c03.jpg
#   inflating: /kaggle/working/man_images/10-29831e4f1673d7649d1aa5333d4ccb6aa15d5ebf.jpg
#   inflating: /kaggle/working/man_images/168-28f5c76bcbfec698b0f9ea5a8a4be7bfbf6f10a7.jpg
#   inflating: /kaggle/working/man_images/114-eb023637363118fe4ed4c82fbc6c216fd7c90a0a.jpg
#   inflating: /kaggle/working/man_images/149-072429e5c9c92e966a0a6088c3436e568478049c.jpg
#   inflating: /kaggle/working/man_images/224-95dac3ad423d4996697f1db896d49ea46ae1d6ed.jpg
#   inflating: /kaggle/working/man_images/76-a9c5346f7dfa52c288d4534aa01dbd8ac7468df6.jpg
#   inflating: /kaggle/working/man_images/70-41ce3cdb8644f45370c9dbbe957528d2f09d81ef.jpg
#   inflating: /kaggle/working/man_images/165-5f1bee56f793cfce19d4abad116d066e2f4d1e54.jpg
#   inflating: /kaggle/working/man_images/137-569adc66b7acf822d4767ca7cb77876add7c00e0.jpg
#   inflating: /kaggle/working/man_images/21-27f439093a9375682d5e500f8ef728d7137938f8.jpg
#   inflating: /kaggle/working/man_images/35-ee4cd224b0050cb87608172116d401bab29e7d13.jpg
#   inflating: /kaggle/working/man_images/69-c110037d8f517d4f6da9768f4976633dcc700959.jpg
#   inflating: /kaggle/working/man_images/141-1db8e094ed9ad915bfe1544d4516ac5b57cca28a.jpg
#   inflating: /kaggle/working/man_images/156-c7534f8c40b3fc5ef00f844998a5d6b3a0f8e681.jpg
#   inflating: /kaggle/working/man_images/210-b88872adc78f71358de4df2261de3db7b1064025.jpg
#   inflating: /kaggle/working/man_images/37-c929bc457cddcd71a18e23a0c0f86ad804a28376.jpg
#   inflating: /kaggle/working/man_images/29-89f50f392e38baf86a340a012a9258c305634f90.jpg
#   inflating: /kaggle/working/man_images/162-c0bb6d993960212ca6202fd00918f3aee2155d40.jpg
#   inflating: /kaggle/working/man_images/102-3b8b3ccc35e4e45b0138362b0f1afb2149893fcf.jpg
#   inflating: /kaggle/working/man_images/143-2d84ddadf1c72e64a1e71cdf13356d3afc0ad6b5.jpg
#   inflating: /kaggle/working/man_images/104-cd453491277a81bcf4258ff21d31ef07af39e902.jpg
#   inflating: /kaggle/working/man_images/185-76a7f051a99e952d1e00a83d62006f46f0fcaa5f.jpg
#   inflating: /kaggle/working/man_images/107-c8d0f12103558758da606f2fdddf2923dc69a7cd.jpg
#   inflating: /kaggle/working/man_images/181-f6a579751bc46cd48b5899819c9ad207241351a9.jpg
#   inflating: /kaggle/working/man_images/159-42d3b46127e69446387c1a12bc9da74f420d1ba2.jpg
#   inflating: /kaggle/working/man_images/58-a356f999969b5695dbc8a8335f18c00d31a68f97.jpg
#   inflating: /kaggle/working/man_images/97-5fdf665fed863e61534df8062a10687a8b8dba11.jpg
#   inflating: /kaggle/working/man_images/87-544b49ee8e367264dd2ee507096f2582b166ad75.jpg
#   inflating: /kaggle/working/man_images/208-2359ab859a227f61e0100b5e6c1e468d618a3036.jpg
#   inflating: /kaggle/working/man_images/183-82301249c729816252ebd02f0612326437a336f6.jpg
#   inflating: /kaggle/working/man_images/127-7aaa68c2081f6a7ce5e0478861440d1fb9083cbb.jpg
#   inflating: /kaggle/working/man_images/57-2df1dbc21bae31c786bba7c323fe1e1a141547f4.jpg
#   inflating: /kaggle/working/man_images/157-7537c6bf9de417c2e6a5521925d887eb65921015.jpg
#   inflating: /kaggle/working/man_images/144-6328b79052b009a02305d31d3c6573e5e89cee96.jpg
#   inflating: /kaggle/working/man_images/175-2fa941d4d2bf3a6a38e81fae9bda5296f9dfc96f.jpg
#   inflating: /kaggle/working/man_images/20-63e4a49c467ad0e45899feff56744fe3f1bafcf1.jpg
#   inflating: /kaggle/working/man_images/86-e6eb23dd83fb37dd008fe6a8317dbbe0cdaca524.jpg
#   inflating: /kaggle/working/man_images/195-b632e515a35e48a9e43b8106fce502f44c8a0421.jpg
#   inflating: /kaggle/working/man_images/80-68064a4c134344871d189bd41eeb57a33ab6199e.jpg
#   inflating: /kaggle/working/man_images/217-700be7d4164864476e26b6c90d0202c76002e692.jpg
#   inflating: /kaggle/working/man_images/82-76dcb08e66c515d09311aacc59f9abe25a13561a.jpg
#   inflating: /kaggle/working/man_images/148-9e696845397bf5e46417f04d5dcdef17e9736f6a.jpg
#   inflating: /kaggle/working/man_images/73-19ab70b3bdb083adeb83a0c25c3c9fe4a26f8a15.jpg
#   inflating: /kaggle/working/man_images/101-9b626e23796ae95d2d368db028e5657b8e6e967f.jpg
#   inflating: /kaggle/working/man_images/61-c43b58043b38071a02172ab5e06703a48ac7ff91.jpg
#   inflating: /kaggle/working/man_images/39-e71de7e3d32fb2aaa8dd89a0bd27eab9d635f9a1.jpg
#   inflating: /kaggle/working/man_images/8-7af78791b0e34919155da64c5a75e152a0b04084.jpg
#   inflating: /kaggle/working/man_images/85-daecde7fd0b56412cc1e7743bf875731ad7f29e3.jpg
#   inflating: /kaggle/working/man_images/218-e415884de459c9e4104f4446f7e929283d13888c.jpg
#   inflating: /kaggle/working/man_images/226-3ffeab320bbd8d609f575024b0a42a7350bc390b.jpg
#   inflating: /kaggle/working/man_images/182-c6b06382a9b090dffd363aa0a4fba3ebfcef2c14.jpg
#   inflating: /kaggle/working/man_images/177-852d9de16df7b185447d90543ed940235216ca9d.jpg
#   inflating: /kaggle/working/man_images/121-ce0d0ed87b32f47e00265bb0fe20a8fc29eb7c78.jpg
#   inflating: /kaggle/working/man_images/140-b8324d31c03e897d541e67594c941505c8207acb.jpg
#   inflating: /kaggle/working/man_images/98-cee3e1443045823157762ccccaf8d3f674195824.jpg
#   inflating: /kaggle/working/man_images/130-7eda21cae9804b9ba1199e1aa2e632544ac2bd48.jpg
#   inflating: /kaggle/working/man_images/75-dc7ec7b1f32d2b30e65dbacd4f55286fd7d09e7e.jpg
#   inflating: /kaggle/working/man_images/133-7f5e2150726c392f455d33afb32c3d2d7bd0f549.jpg
#   inflating: /kaggle/working/man_images/154-431c8a3b185ccf9d4ae8dbc6be5a064b01f07749.jpg
#   inflating: /kaggle/working/man_images/110-df4332153583373776f4cea90a2fec7974862f7d.jpg
#   inflating: /kaggle/working/man_images/16-0a314ce4c9d5f267523bf0ab727a44e516125b0e.jpg
#   inflating: /kaggle/working/man_images/28-95e65a1969e6a222b3deeab33cc33991758c88a7.jpg
#   inflating: /kaggle/working/man_images/66-534f9ba604c7b7ce5a6141a1d4c8f03b6dede6a2.jpg
#   inflating: /kaggle/working/man_images/131-6b3b6474bb7f7e6a50c7e7256b586efbeb0de73f.jpg
#   inflating: /kaggle/working/man_images/174-52ce05a61691b8d9106fd575e8ba06970f8d013e.jpg
#   inflating: /kaggle/working/man_images/68-abf9dcfb83a069e6980b0c493f4f5d784a40bec9.jpg
#   inflating: /kaggle/working/man_images/209-5874592c7c72f1cf34e5776ee04bb2fec3777b13.jpg
#   inflating: /kaggle/working/man_images/6-a07353303b6f1fab2360c614aef4adf6ab5d9fef.jpg
#   inflating: /kaggle/working/man_images/189-53cdd6c0693efd8d69ab852db61c51684877d20b.jpg
#   inflating: /kaggle/working/man_images/126-398d475147da424147643e9f67ae80c82fb4c38e.jpg
#   inflating: /kaggle/working/man_images/79-157ab3a81e8084d0773c143e4434139021e05ec1.jpg
#   inflating: /kaggle/working/man_images/48-78c502b2b6b798140bc5cfc64cf005770457091d.jpg
#   inflating: /kaggle/working/man_images/192-db516e19f9e12423163c010ee14d2d01b4ebe7fa.jpg
#   inflating: /kaggle/working/man_images/43-40d85b6a8a856fb63f859a55dfd42a2f3ec74992.jpg
#   inflating: /kaggle/working/man_images/142-4954a796021ae285c7227e83dd2861554ffe4ac4.jpg
#   inflating: /kaggle/working/man_images/96-ce4fe1bd80d2bc8fc3a5e95f138b6b2a0474beec.jpg
#   inflating: /kaggle/working/man_images/171-1396822be1d3230737585bdcc34572b0802a2f58.jpg
#   inflating: /kaggle/working/man_images/146-d90212dd7989f6f5102429d4a599187b3c499626.jpg
#   inflating: /kaggle/working/man_images/19-b19e63d4a1823a0013aa89906b1bccadc49308f0.jpg
#   inflating: /kaggle/working/man_images/89-1459ec3eb2bc5bbfd69df4106d5ae4c293d8c8d1.jpg
#   inflating: /kaggle/working/man_images/201-860af0aefc4d092e8def8cda8835ba7d39ea1c72.jpg
#   inflating: /kaggle/working/man_images/152-fce543d1c5b77c72767d9fc604cce77ff961be27.jpg
#   inflating: /kaggle/working/man_images/196-1eecf6cdad37e56fa30f32ae3b521aa28d070f97.jpg
#   inflating: /kaggle/working/man_images/124-f168b481afc7217580fb01d5c9b1b04ed4d4cff5.jpg
#   inflating: /kaggle/working/man_images/59-545accfadc93db11bea476e90830d6177eaa5fd5.jpg
#   inflating: /kaggle/working/man_images/72-502cdde950ab8bdcc77acba74aa6ffd12516acf9.jpg
#   inflating: /kaggle/working/man_images/49-970361b2c990f9e462ec31e1e2267a5414923748.jpg
#   inflating: /kaggle/working/man_images/187-ae2568d57953f2c627e517a2059a0579a35807ed.jpg
#   inflating: /kaggle/working/man_images/150-7030d988e396c55afdf3ba0f7b4f7e7fd088d7b2.jpg
#   inflating: /kaggle/working/man_images/50-a36a4db763138880ec8f482c3c696a8687e2075e.jpg
#   inflating: /kaggle/working/man_images/123-e82a7f023e09a7e535a4fe2769c9ddc4a3e7c237.jpg
#   inflating: /kaggle/working/man_images/173-d2cd310ffec49a8b38521512b9fe5743ab589c4a.jpg
#   inflating: /kaggle/working/man_images/132-b48e1e36b19a25e4f620f3e99fd129c6f7c6668e.jpg
#   inflating: /kaggle/working/man_images/78-3a8d6011724d543933c28c27e5c36e2775768431.jpg
#   inflating: /kaggle/working/man_images/84-0978baa569e694d7da053d3eb153fea88f3cbee3.jpg
#   inflating: /kaggle/working/man_images/167-279779972d921a9c16c38237d6a258e352f522d9.jpg
#   inflating: /kaggle/working/man_images/40-c5f0d3d682c0fc30b463d651815b4ab7949531e3.jpg
#   inflating: /kaggle/working/man_images/117-379648b421d349cf2d820a6f2031f7afb5387575.jpg
#   inflating: /kaggle/working/man_images/22-102932b43a1b5cdccd9a9a7423310a35fcbea05e.jpg
#   inflating: /kaggle/working/man_images/27-95a4e5d05869d2e49663c1f5c5c7a1e647689710.jpg
#   inflating: /kaggle/working/man_images/139-29d98cc4c7bc7d3a9dbbc08f6a1e7b96de913b04.jpg
#   inflating: /kaggle/working/man_images/105-cad33d4081b44a15dbca3376aaddfe9554d66935.jpg
#   inflating: /kaggle/working/man_images/169-73507d698916991d3d1e477e1a5a4eeff706da5f.jpg
#   inflating: /kaggle/working/man_images/25-ccac0ebc4627c34fa5adaeb5aa157e81729df88a.jpg
#   inflating: /kaggle/working/man_images/115-49838b5a3c19abf64a9ac9bbfcb8b98c28f073f5.jpg
#   inflating: /kaggle/working/man_images/118-a1828f63ac74a9c21176d35d566f710214625fe9.jpg
#   inflating: /kaggle/working/man_images/163-a5814825680d4b023ae2ad53fbb3983efc0ee6e4.jpg
#   inflating: /kaggle/working/man_images/62-0a8ee3a1d7db850fb11ee436e5185138c03a2152.jpg
#   inflating: /kaggle/working/man_images/95-7dd22650522797ed19e94fd160dc5385136474c9.jpg
#   inflating: /kaggle/working/man_images/56-120941635e4db7ae3207d7ead9cba3c9779addbc.jpg
#   inflating: /kaggle/working/man_images/214-0b43992dcc9f41e8799ba8b925773db0a51eb6ec.jpg
#   inflating: /kaggle/working/man_images/17-800149aadb8e46ebeaf3b203009f9c8fc65c7390.jpg
#   inflating: /kaggle/working/man_images/24-cd08134cef766d94f95fc09bd8bbd68a05f47b40.jpg
#   inflating: /kaggle/working/man_images/94-73bf8133e566f839d1f27069245d953b1d53f0c2.jpg
#   inflating: /kaggle/working/man_images/205-13b4919db6b9ccd11f67d5fecab990eae48b7809.jpg
#   inflating: /kaggle/working/man_images/11-392a0d7cc06978944bdd1dd5952552873f78dbec.jpg
#   inflating: /kaggle/working/man_images/83-ea70116be43d545d3a42c310bbe9c4a9887c0d51.jpg
#   inflating: /kaggle/working/man_images/54-6edb676bcb731cb8e688b4aadc2fce078ac089af.jpg
#   inflating: /kaggle/working/man_images/207-462f40572368238e3a8f3d2a8ea74f6f6f523670.jpg
#   inflating: /kaggle/working/man_images/90-55f9d88e266bfe9d6b5b2ef92c834c5c639a2a47.jpg
#   inflating: /kaggle/working/man_images/9-de3ab18d965f29029a3c8ecba18bedf72d65b90d.jpg
#   inflating: /kaggle/working/man_images/53-35d055846624ef4813cce623810837823ccee117.jpg
#   inflating: /kaggle/working/man_images/108-c510b5c6c7d66c503f0683af25299952515bc20a.jpg
#   inflating: /kaggle/working/man_images/134-2142079154bb86105ad5101eb3510c25a4664b06.jpg
#   inflating: /kaggle/working/man_images/199-36287fc71ec0815059787933546e5896a381e9f2.jpg
#   inflating: /kaggle/working/man_images/99-c0fdd6f5bf9063b3d2e26a6e7aa88bda7ee743fa.jpg
#   inflating: /kaggle/working/man_images/120-c8f84f3deaaead10ae5be3b5a4490e22dce9db92.jpg
#   inflating: /kaggle/working/man_images/203-1352f968b9b42c7d2b13321e2dc5e185c8e9fb2a.jpg
#   inflating: /kaggle/working/man_images/88-cac9202f959dcb5b8ef814f3562949df1d3b4a56.jpg
#   inflating: /kaggle/working/man_images/151-d44deb9ed9051161ba8866f8a4db1f3bf522d008.jpg
#   inflating: /kaggle/working/man_images/221-7495618bfb6ab8ac5cc3f6fc4a3022e8f531881e.jpg
#   inflating: /kaggle/working/man_images/138-f925817a58a75e7224a71e0b3b7409e7ae289cdc.jpg
#   inflating: /kaggle/working/man_images/112-1bae0dd66b21d9b9a48d5043020becd371e226ee.jpg
#   inflating: /kaggle/working/man_images/26-231a95cbdceb012a763ccbce63f9af5ac851c242.jpg
#   inflating: /kaggle/working/man_images/213-2aab4e07ec5d0c1f45aba1964bd2fa5fa40a83d0.jpg
#   inflating: /kaggle/working/man_images/193-88f33f7c45ba7a0e09905ecbf29d42bb46c5dffe.jpg
#   inflating: /kaggle/working/man_images/92-d4e876bf0806e6e882c60b6ccb60b76c1a34ea35.jpg
#   inflating: /kaggle/working/man_images/18-5d75dec994567d45182332d17c50a8b0de280380.jpg
#   inflating: /kaggle/working/man_images/111-f3b0d700dc5d0a05221b45eef145e8518b63f15d.jpg
#   inflating: /kaggle/working/man_images/215-5b786151ad1378219a2e3f411c703bab989d2d5d.jpg
#   inflating: /kaggle/working/man_images/5-3bb373fe279578ce6b663a257d4d785b75d4410f.jpg
#   inflating: /kaggle/working/man_images/202-24d72823b6aeff6d75b0266460f2917f21b8c8bb.jpg
#   inflating: /kaggle/working/man_images/184-2486352e4edd2e61f0fe77bc5110085ea6c712e0.jpg
#   inflating: /kaggle/working/man_images/135-6c8e5f1e69786483991dc4c26471375fa3015cb5.jpg
#   inflating: /kaggle/working/man_images/91-32ae84fe4105f1fa5ed10d508072ea274fce02a6.jpg
#   inflating: /kaggle/working/man_images/0-7e706b4b571eb1d9c040a3cb4c737c222438fe72.jpg
#   inflating: /kaggle/working/man_images/32-1c19b318b91f1d2488df3e840eb023e2bed7e4f4.jpg
#   inflating: /kaggle/working/man_images/223-50d760c6f13ead2c8a244eb79bddb873c44423ec.jpg
#   inflating: /kaggle/working/man_images/52-9f9145000ec002e639448c5e465d93a92f6ae279.jpg
#   inflating: /kaggle/working/man_images/170-7daf73dc48879b2d8d435efdd9b4654c8bd26227.jpg
#   inflating: /kaggle/working/man_images/71-e0404cbc2efe0f4398d7743ba1fa7318e95298d1.jpg
#   inflating: /kaggle/working/man_images/197-f7b883cb7419ca93b509d1a80c0469606eebadaa.jpg
#   inflating: /kaggle/working/man_images/128-3c03f6a3d0b43d5a0d059b57412b6f601913755a.jpg
#   inflating: /kaggle/working/man_images/106-e4eeb43e2c0ab23a3d02f68a0cd0dcfc097f78d7.jpg
#   inflating: /kaggle/working/man_images/160-3c976a129227465d48907bf9e3ef787af1948311.jpg
#   inflating: /kaggle/working/man_images/63-fe8e200708ba50313e649abf71e2e5c21cdf5ecf.jpg
#   inflating: /kaggle/working/man_images/113-1d0ba66049b47b49d19e918227f616b7e00cccef.jpg
#   inflating: /kaggle/working/man_images/212-167a019ba34fec4632efc32adfae5afa4a4bdb8f.jpg
#   inflating: /kaggle/working/man_images/44-083a50b4ad186d8c3fb0452336ac4b54afc38a85.jpg
#   inflating: /kaggle/working/man_images/13-6ffe8d48024451a6caa4776a031999524f9082e9.jpg
#   inflating: /kaggle/working/man_images/172-b117514446eeab77f56b6200de24475fda17eaa1.jpg
#   inflating: /kaggle/working/man_images/200-f7869088e952915e22b52d1ab7846fb3659e86b0.jpg
#   inflating: /kaggle/working/man_images/64-97ca2af9234f456afd5fdd3b3cb017cd3b3c42d0.jpg
#   inflating: /kaggle/working/man_images/51-3dd723f9ba5c2668d36f03492ccda440a69d686c.jpg

# %%
os.environ['INSTANCE_DIR'] = "./freddie"
os.environ['CLASS_DIR'] = "/kaggle/working/man_images"
os.environ['MODEL_NAME'] = "/kaggle/working/civitai_weights"

# %% [markdown]
# ###  Промпты для тестирования

# %%
token = "sks"
promt_list = [
    {
     "name": "bookshop",
     "prompt":f"close up portrait of {token} face, in the bookshop, books, soft light, 4K, raw, hrd, hd, high quality, realism, sharp focus",
     "n_prompt":"naked, nsfw, deformed, distorted, disfigured, poorly drawn, bad anatomy, extra limb, missing limb, floating limbs, mutated hands disconnected limbs, mutation, ugly, blurry, amputation",
    },
    {
     "name": "russian forest",
     "prompt":f"сlose up portrait of {token} face, in the forest, 4K, raw, hrd, hd, high quality, realism, sharp focus",
     "n_prompt":"naked, nsfw, deformed, distorted, disfigured, weapon, gun, war, poorly drawn, bad anatomy, extra limb, missing limb, floating limbs, mutated hands disconnected limbs, mutation, ugly, blurry, amputation",
    },
    {
     "name": "street",
     "prompt":f"сlose up portrait of {token} face, on the street, lights, midnight, Moscow, 4K, raw, hrd, hd, high quality, realism, sharp focus",
     "n_prompt":"naked, nsfw, deformed, distorted, disfigured, poorly drawn, bad anatomy, extra limb, missing limb, floating limbs, mutated hands, mutation, ugly, blurry",
    },
    {
     "name": "spaceship",
     "prompt":f"сlose up portrait of {token} face, in the spaceship, stars, planets, 4K, raw, hrd, hd, high quality, realism, sharp focus",
     "n_prompt":"naked, nsfw, deformed, distorted, disfigured, poorly drawn, bad anatomy, extra limb, missing limb, floating limbs, mutated hands, mutation, ugly, blurry",
    },
     {
     "name": "music festival",
     "prompt":f"сlose up portrait of {token} face, on the music festival, scene, music, 4K, raw, hrd, hd, high quality, realism, sharp focus",
     "n_prompt":"naked, nsfw, deformed, distorted, disfigured, poorly drawn, bad anatomy, extra limb, missing limb, floating limbs, mutated hands, mutation, ugly, blurry",
    },
]

# %%
def generate_images(pipe, save_folder, seed):
    repeat = 2
    num_samples = 2
    guidance_scale = 7.5
    num_inference_steps = 35
    height = 768
    width = 1024

    save_mode = "base_model"

    for idx, sample in enumerate(promt_list):
      prompt = sample.get("prompt")
      negative_prompt = sample.get("n_prompt")
      name = sample.get("name")
      image_list = []
      for _ in range(repeat):
        generator = torch.Generator("cuda").manual_seed(seed)
        with autocast("cuda"), torch.inference_mode():
            images = pipe(
                prompt,
                height=height,
                width=width,
                negative_prompt=negative_prompt,
                num_images_per_prompt=num_samples,
                num_inference_steps=num_inference_steps,
                guidance_scale=guidance_scale,
                generator=generator
            ).images
        image_list.extend(images)
        seed+=1

      img_grid = image_grid(image_list, num_samples, repeat)
      save_path = os.path.join(save_folder, save_mode, f"{height}x{width}")
      os.makedirs(save_path, exist_ok=True)
      img_grid.save(os.path.join(save_path, f"{name}.jpg"))

# %%
def image_grid(imgs, rows, cols):
    assert len(imgs) == rows*cols

    w, h = imgs[0].size
    grid = Image.new('RGB', size=(cols*w, rows*h))
    grid_w, grid_h = grid.size

    for i, img in enumerate(imgs):
        grid.paste(img, box=(i%cols*w, i//cols*h))
    return grid

# %% [markdown]
# ##  Обучаем lora адаптер

# %%
import gc
torch.cuda.empty_cache()
gc.collect()
# Out:
# 60

# %%
os.environ['OUTPUT_DIR'] = "/kaggle/working/output_lora_rank4"
# !python3 diffusers/examples/dreambooth/train_dreambooth_lora.py \
  --pretrained_model_name_or_path=$MODEL_NAME \
  --instance_data_dir=$INSTANCE_DIR \
  --output_dir=$OUTPUT_DIR \
  --instance_prompt="a photo of sks face" \
  --seed=13498 \
  --resolution=512 \
  --train_batch_size=1 \
  --learning_rate=1e-4 \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --gradient_accumulation_steps=1 \
  --max_train_steps=1000 \
  --checkpointing_steps=1000\
  --validation_prompt="A photo of sks face on the music festival" \
  --validation_epochs=500 \
  --use_8bit_adam \
  --mixed_precision="no"\
  --rank=4
# Out:
# 2024-04-11 19:26:08.096325: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-11 19:26:08.096407: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-11 19:26:08.097915: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# You are using a model of type clip_text_model to instantiate a model of type . This is not supported for all configurations of models and can yield errors.
# {'variance_type'} was not found in config. Values will be initialized to default values.
# /opt/conda/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# Steps:   2%|▏         | 19/1000 [00:18<14:46,  1.11it/s, loss=0.0026, lr=0.0001]
# Loading pipeline components...:   0%|                     | 0/7 [00:00<?, ?it/s]/opt/conda/lib/python3.10/site-packages/transformers/models/clip/feature_extraction_clip.py:28: FutureWarning: The class CLIPFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use CLIPImageProcessor instead.
#   warnings.warn(
# Loaded feature_extractor as CLIPFeatureExtractor from `feature_extractor` subfolder of /kaggle/working/civitai_weights.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of /kaggle/working/civitai_weights.
#
# Loading pipeline components...:  57%|███████▍     | 4/7 [00:00<00:00,  7.37it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of /kaggle/working/civitai_weights.
# Loaded vae as AutoencoderKL from `vae` subfolder of /kaggle/working/civitai_weights.
#
# Loading pipeline components...:  86%|███████████▏ | 6/7 [00:00<00:00,  6.04it/s]Loaded scheduler as DDIMScheduler from `scheduler` subfolder of /kaggle/working/civitai_weights.
# Loading pipeline components...: 100%|█████████████| 7/7 [00:00<00:00,  7.29it/s]
# {'solver_type', 'variance_type', 'lower_order_final', 'lambda_min_clipped', 'use_lu_lambdas', 'use_karras_sigmas', 'euler_at_final', 'final_sigmas_type', 'algorithm_type', 'solver_order'} was not found in config. Values will be initialized to default values.
# Steps: 100%|████████| 1000/1000 [17:15<00:00,  1.00it/s, loss=0.0191, lr=0.0001]Model weights saved in /kaggle/working/output_lora_rank4/checkpoint-1000/pytorch_lora_weights.safetensors
# Steps: 100%|█████████| 1000/1000 [17:15<00:00,  1.00it/s, loss=0.202, lr=0.0001]Model weights saved in /kaggle/working/output_lora_rank4/pytorch_lora_weights.safetensors
#
# Loading pipeline components...:   0%|                     | 0/7 [00:00<?, ?it/s]Loaded feature_extractor as CLIPFeatureExtractor from `feature_extractor` subfolder of /kaggle/working/civitai_weights.
# Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of /kaggle/working/civitai_weights.
#
# Loading pipeline components...:  29%|███▋         | 2/7 [00:00<00:01,  4.65it/s]Loaded unet as UNet2DConditionModel from `unet` subfolder of /kaggle/working/civitai_weights.
#
# Loading pipeline components...:  43%|█████▌       | 3/7 [00:02<00:04,  1.08s/it]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of /kaggle/working/civitai_weights.
#
# Loading pipeline components...:  57%|███████▍     | 4/7 [00:03<00:02,  1.13it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of /kaggle/working/civitai_weights.
# Loaded vae as AutoencoderKL from `vae` subfolder of /kaggle/working/civitai_weights.
#
# Loading pipeline components...:  86%|███████████▏ | 6/7 [00:03<00:00,  1.88it/s]Loaded scheduler as DDIMScheduler from `scheduler` subfolder of /kaggle/working/civitai_weights.
# Loading pipeline components...: 100%|█████████████| 7/7 [00:03<00:00,  1.90it/s]
# Loading unet.
# {'solver_type', 'variance_type', 'lower_order_final', 'lambda_min_clipped', 'use_lu_lambdas', 'use_karras_sigmas', 'euler_at_final', 'final_sigmas_type', 'algorithm_type', 'solver_order'} was not found in config. Values will be initialized to default values.
# Potential NSFW content was detected in one or more images. A black image will be returned instead. Try again with a different prompt and/or seed.
# Potential NSFW content was detected in one or more images. A black image will be returned instead. Try again with a different prompt and/or seed.
# Steps: 100%|█████████| 1000/1000 [17:43<00:00,  1.06s/it, loss=0.202, lr=0.0001]

# %%
torch.cuda.empty_cache()
gc.collect()
# Out:
# 0

# %%
os.environ['OUTPUT_DIR'] = "/kaggle/working/output_lora_rank16"
# !python3 diffusers/examples/dreambooth/train_dreambooth_lora.py \
   --pretrained_model_name_or_path=$MODEL_NAME  \
  --instance_data_dir=$INSTANCE_DIR \
  --output_dir=$OUTPUT_DIR \
  --instance_prompt="a photo of sks face" \
  --seed=13498 \
  --resolution=512 \
  --train_batch_size=1 \
  --learning_rate=1e-4 \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --gradient_accumulation_steps=1 \
  --max_train_steps=1000 \
  --checkpointing_steps=1000\
  --validation_prompt="A photo of sks face on the music festival" \
  --validation_epochs=500 \
  --use_8bit_adam \
  --mixed_precision="no"\
  --rank=16
# Out:
# 2024-04-11 19:44:09.665960: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-11 19:44:09.666036: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-11 19:44:09.667651: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# You are using a model of type clip_text_model to instantiate a model of type . This is not supported for all configurations of models and can yield errors.
# {'variance_type'} was not found in config. Values will be initialized to default values.
# /opt/conda/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# Steps:   2%|▏        | 19/1000 [00:19<16:27,  1.01s/it, loss=0.00303, lr=0.0001]
# Loading pipeline components...:   0%|                     | 0/7 [00:00<?, ?it/s]/opt/conda/lib/python3.10/site-packages/transformers/models/clip/feature_extraction_clip.py:28: FutureWarning: The class CLIPFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use CLIPImageProcessor instead.
#   warnings.warn(
# Loaded feature_extractor as CLIPFeatureExtractor from `feature_extractor` subfolder of /kaggle/working/civitai_weights.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of /kaggle/working/civitai_weights.
# Loaded scheduler as DDIMScheduler from `scheduler` subfolder of /kaggle/working/civitai_weights.
# Loaded vae as AutoencoderKL from `vae` subfolder of /kaggle/working/civitai_weights.
#
# Loading pipeline components...:  86%|███████████▏ | 6/7 [00:00<00:00, 16.99it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of /kaggle/working/civitai_weights.
# Loading pipeline components...: 100%|█████████████| 7/7 [00:00<00:00,  7.59it/s]
# {'use_lu_lambdas', 'euler_at_final', 'lambda_min_clipped', 'lower_order_final', 'solver_type', 'algorithm_type', 'use_karras_sigmas', 'variance_type', 'final_sigmas_type', 'solver_order'} was not found in config. Values will be initialized to default values.
# Steps: 100%|████████| 1000/1000 [17:31<00:00,  1.00s/it, loss=0.0275, lr=0.0001]Model weights saved in /kaggle/working/output_lora_rank16/checkpoint-1000/pytorch_lora_weights.safetensors
# Steps: 100%|█████████| 1000/1000 [17:31<00:00,  1.00s/it, loss=0.173, lr=0.0001]Model weights saved in /kaggle/working/output_lora_rank16/pytorch_lora_weights.safetensors
#
# Loading pipeline components...:   0%|                     | 0/7 [00:00<?, ?it/s]Loaded unet as UNet2DConditionModel from `unet` subfolder of /kaggle/working/civitai_weights.
#
# Loading pipeline components...:  14%|█▊           | 1/7 [00:02<00:13,  2.25s/it]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of /kaggle/working/civitai_weights.
#
# Loading pipeline components...:  29%|███▋         | 2/7 [00:02<00:05,  1.16s/it]Loaded feature_extractor as CLIPFeatureExtractor from `feature_extractor` subfolder of /kaggle/working/civitai_weights.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of /kaggle/working/civitai_weights.
# Loaded scheduler as DDIMScheduler from `scheduler` subfolder of /kaggle/working/civitai_weights.
# Loaded vae as AutoencoderKL from `vae` subfolder of /kaggle/working/civitai_weights.
#
# Loading pipeline components...:  86%|███████████▏ | 6/7 [00:03<00:00,  2.88it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of /kaggle/working/civitai_weights.
#
# Loading pipeline components...: 100%|█████████████| 7/7 [00:03<00:00,  1.93it/s]
# Loading unet.
# {'use_lu_lambdas', 'euler_at_final', 'lambda_min_clipped', 'lower_order_final', 'solver_type', 'algorithm_type', 'use_karras_sigmas', 'variance_type', 'final_sigmas_type', 'solver_order'} was not found in config. Values will be initialized to default values.
# Potential NSFW content was detected in one or more images. A black image will be returned instead. Try again with a different prompt and/or seed.
# Steps: 100%|█████████| 1000/1000 [17:59<00:00,  1.08s/it, loss=0.173, lr=0.0001]

# %%
torch.cuda.empty_cache()
gc.collect()
# Out:
# 0

# %%
os.environ['OUTPUT_DIR'] = "/kaggle/working/output_lora_rank24"
# !python3 diffusers/examples/dreambooth/train_dreambooth_lora.py \
 --pretrained_model_name_or_path=$MODEL_NAME  \
  --instance_data_dir=$INSTANCE_DIR \
  --output_dir=$OUTPUT_DIR \
  --instance_prompt="a photo of sks face" \
  --seed=13498 \
  --resolution=512 \
  --train_batch_size=1 \
  --learning_rate=1e-4 \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --gradient_accumulation_steps=1 \
  --max_train_steps=1000 \
  --checkpointing_steps=1000\
  --validation_prompt="A photo of sks face on the music festival" \
  --validation_epochs=500 \
  --use_8bit_adam \
  --mixed_precision="no"\
  --rank=24
# Out:
# 2024-04-11 20:02:26.867868: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-11 20:02:26.867926: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-11 20:02:26.869328: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# You are using a model of type clip_text_model to instantiate a model of type . This is not supported for all configurations of models and can yield errors.
# {'variance_type'} was not found in config. Values will be initialized to default values.
# /opt/conda/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# Steps:   2%|▏        | 19/1000 [00:19<16:29,  1.01s/it, loss=0.00411, lr=0.0001]
# Loading pipeline components...:   0%|                     | 0/7 [00:00<?, ?it/s]Loaded scheduler as DDIMScheduler from `scheduler` subfolder of /kaggle/working/civitai_weights.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of /kaggle/working/civitai_weights.
#
# Loading pipeline components...:  29%|███▋         | 2/7 [00:00<00:01,  3.54it/s]/opt/conda/lib/python3.10/site-packages/transformers/models/clip/feature_extraction_clip.py:28: FutureWarning: The class CLIPFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use CLIPImageProcessor instead.
#   warnings.warn(
# Loaded feature_extractor as CLIPFeatureExtractor from `feature_extractor` subfolder of /kaggle/working/civitai_weights.
# Loaded vae as AutoencoderKL from `vae` subfolder of /kaggle/working/civitai_weights.
#
# Loading pipeline components...:  71%|█████████▎   | 5/7 [00:00<00:00,  6.73it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of /kaggle/working/civitai_weights.
# Loading pipeline components...: 100%|█████████████| 7/7 [00:00<00:00,  7.71it/s]
# {'algorithm_type', 'variance_type', 'final_sigmas_type', 'lower_order_final', 'euler_at_final', 'use_lu_lambdas', 'solver_order', 'lambda_min_clipped', 'solver_type', 'use_karras_sigmas'} was not found in config. Values will be initialized to default values.
# Steps: 100%|████████| 1000/1000 [17:31<00:00,  1.00s/it, loss=0.0123, lr=0.0001]Model weights saved in /kaggle/working/output_lora_rank24/checkpoint-1000/pytorch_lora_weights.safetensors
# Steps: 100%|█████████| 1000/1000 [17:31<00:00,  1.00s/it, loss=0.199, lr=0.0001]Model weights saved in /kaggle/working/output_lora_rank24/pytorch_lora_weights.safetensors
#
# Loading pipeline components...:   0%|                     | 0/7 [00:00<?, ?it/s]Loaded scheduler as DDIMScheduler from `scheduler` subfolder of /kaggle/working/civitai_weights.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of /kaggle/working/civitai_weights.
#
# Loading pipeline components...:  29%|███▋         | 2/7 [00:00<00:01,  3.31it/s]Loaded feature_extractor as CLIPFeatureExtractor from `feature_extractor` subfolder of /kaggle/working/civitai_weights.
# Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of /kaggle/working/civitai_weights.
#
# Loading pipeline components...:  57%|███████▍     | 4/7 [00:01<00:00,  4.05it/s]Loaded vae as AutoencoderKL from `vae` subfolder of /kaggle/working/civitai_weights.
#
# Loading pipeline components...:  71%|█████████▎   | 5/7 [00:01<00:00,  3.75it/s]Loaded unet as UNet2DConditionModel from `unet` subfolder of /kaggle/working/civitai_weights.
#
# Loading pipeline components...:  86%|███████████▏ | 6/7 [00:03<00:00,  1.22it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of /kaggle/working/civitai_weights.
# Loading pipeline components...: 100%|█████████████| 7/7 [00:03<00:00,  1.98it/s]
# Loading unet.
# {'algorithm_type', 'variance_type', 'final_sigmas_type', 'lower_order_final', 'euler_at_final', 'use_lu_lambdas', 'solver_order', 'lambda_min_clipped', 'solver_type', 'use_karras_sigmas'} was not found in config. Values will be initialized to default values.
# Steps: 100%|█████████| 1000/1000 [18:00<00:00,  1.08s/it, loss=0.199, lr=0.0001]

# %%
torch.cuda.empty_cache()
gc.collect()
# Out:
# 0

# %%
model_path = "/kaggle/working/civitai_weights"

# %%
for i in [4, 16, 24]:
    seed=13498
    pipe_lora = StableDiffusionPipeline.from_pretrained(model_path, safety_checker=None, torch_dtype=torch.float16).to("cuda")
    pipe_lora.scheduler = DDIMScheduler.from_config(pipe_lora.scheduler.config)
    pipe_lora.load_lora_weights(f"/kaggle/working/output_lora_rank{i}")
    g_cuda=None
    g_cuda = torch.Generator(device='cuda')
    g_cuda.manual_seed(seed)
    save_path = Path(f'/kaggle/working/report_lora_{i}')
    generate_images(pipe_lora, save_path, seed)
    
    for filename in (save_path / 'base_model/768x1024').iterdir():
        display(IPyImage(filename))
# Out:
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
#   0%|          | 0/35 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
#   0%|          | 0/35 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
#   0%|          | 0/35 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
